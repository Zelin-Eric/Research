# %%
import pandas
import numpy

# %%
print("Data preprocessing")
# Out:
# Data preprocessing

# %%
from moomoo import *

quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)  # 创建行情对象
print(quote_ctx.get_market_snapshot('HK.00700'))  # 获取港股 HK.00700 的快照数据
quote_ctx.close() # 关闭对象，防止连接条数用尽


trd_ctx = OpenSecTradeContext(host='127.0.0.1', port=11111)  # 创建交易对象
print(trd_ctx.place_order(price=500.0, qty=100, code="HK.00700", trd_side=TrdSide.BUY, trd_env=TrdEnv.SIMULATE))  # 模拟交易，下单（如果是真实环境交易，在此之前需要先解锁交易密码）

trd_ctx.close()  # 关闭对象，防止连接条数用尽
# Out:
# 2024-01-17 18:37:03,917 | 31015 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=3, host=127.0.0.1, port=11111, user_id=70911970
# (0,        code  name          update_time  last_price  open_price  high_price  \
# 0  HK.00700  腾讯控股  2024-01-17 13:37:03       274.6       277.0       278.8
#
#    low_price  prev_close_price    volume      turnover  ...  pre_turnover  \
# 0      272.4             282.4  18882636  5.200621e+09  ...           N/A
#
#    pre_change_val pre_change_rate  pre_amplitude  after_price  \
# 0             N/A             N/A            N/A          N/A
#
#    after_high_price after_low_price after_change_val after_change_rate  \
# 0               N/A             N/A              N/A               N/A
#
#   after_amplitude
# 0             N/A
#
# [1 rows x 134 columns])
# 2024-01-17 18:37:04,122 | 31015 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=3
# 2024-01-17 18:37:04,125 | 31015 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=4, host=127.0.0.1, port=11111, user_id=70911970
# (0,        code stock_name trd_side order_type order_status            order_id  \
# 0  HK.00700       腾讯控股      BUY     NORMAL   SUBMITTING  499801530861870632
#
#      qty  price          create_time         updated_time  ...  \
# 0  100.0  500.0  2024-01-17 13:37:04  2024-01-17 13:37:04  ...
#
#    dealt_avg_price  last_err_msg remark time_in_force fill_outside_rth  \
# 0              0.0                                DAY              N/A
#
#   aux_price trail_type trail_value trail_spread currency
# 0       N/A        N/A         N/A          N/A      HKD
#
# [1 rows x 21 columns])
# 2024-01-17 18:37:04,392 | 31015 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=4

# %%
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

ret, data = quote_ctx.get_market_state(['SZ.000001', 'HK.00700'])
if ret == RET_OK:
    print(data)
else:
    print('error:', data)
quote_ctx.close() # 结束后记得关闭当条连接，防止连接条数用尽
# Out:
# 2024-01-17 18:47:51,036 | 31015 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=6, host=127.0.0.1, port=11111, user_id=70911970
#         code stock_name market_state
# 0  SZ.000001       平安银行    AFTERNOON
# 1   HK.00700       腾讯控股    AFTERNOON
# 2024-01-17 18:47:51,229 | 31015 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=6

# %%
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)

code_list = ['HK.00001']
ret, data = quote_ctx.get_owner_plate(code_list)
if ret == RET_OK:
    print(data)
    print(data['code'][0])    # 取第一条的股票代码
    print(data['plate_code'].values.tolist())   # 板块代码转为 list
else:
    print('error:', data)
quote_ctx.close() # 结束后记得关闭当条连接，防止连接条数用尽
# Out:
# 2024-01-17 18:54:04,145 | 31015 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=7, host=127.0.0.1, port=11111, user_id=70911970
#        code name          plate_code plate_name plate_type
# 0  HK.00001   长和  HK.HSI Constituent      恒指成份股      OTHER
# 1  HK.00001   长和       HK.GangGuTong     港股通(沪)      OTHER
# 2  HK.00001   长和           HK.BK1000      做空集合股    CONCEPT
# 3  HK.00001   长和           HK.BK1061       综合企业   INDUSTRY
# 4  HK.00001   长和           HK.BK1107        蓝筹股      OTHER
# 5  HK.00001   长和           HK.BK1331       小米概念    CONCEPT
# 6  HK.00001   长和           HK.BK1600        热度榜      OTHER
# 7  HK.00001   长和           HK.BK1922     港股通(深)      OTHER
# 8  HK.00001   长和           HK.BK1983    香港股票ADR      OTHER
# HK.00001
# ['HK.HSI Constituent', 'HK.GangGuTong', 'HK.BK1000', 'HK.BK1061', 'HK.BK1107', 'HK.BK1331', 'HK.BK1600', 'HK.BK1922', 'HK.BK1983']
# 2024-01-17 18:54:04,659 | 31015 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=7

# %%
data.shape
# Out:
# (9, 5)

# %% [markdown]
# ## Basic Info
# ### HK Stocks

# %%
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111)
ret, data = quote_ctx.get_stock_basicinfo(Market.HK, SecurityType.STOCK)
if ret == RET_OK:
    print("*Connection Successful*")
else:
    print('error:', data)
quote_ctx.close()  # 结束后记得关闭当条连接，防止连接条数用尽
# Out:
# 2024-01-17 19:11:08,368 | 31015 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=10, host=127.0.0.1, port=11111, user_id=70911970
# *Connection Successful*
# ******************************************
# 2024-01-17 19:11:08,922 | 31015 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=10

# %%
data
# Out:
#           code      name  lot_size stock_type stock_child_type stock_owner  \
# 0     HK.00001        长和       500      STOCK              N/A
# 1     HK.00002      中电控股       500      STOCK              N/A
# 2     HK.00003    香港中华煤气      1000      STOCK              N/A
# 3     HK.00004     九龙仓集团      1000      STOCK              N/A
# 4     HK.00005      汇丰控股       400      STOCK              N/A
# ...        ...       ...       ...        ...              ...         ...
# 3048  HK.83690     美团-WR       100      STOCK              N/A
# 3049  HK.86618    京东健康-R        50      STOCK              N/A
# 3050  HK.89618  京东集团-SWR        50      STOCK              N/A
# 3051  HK.89888  百度集团-SWR        50      STOCK              N/A
# 3052  HK.89988  阿里巴巴-SWR       100      STOCK              N/A
#
#      option_type strike_time strike_price suspension listing_date  \
# 0            N/A                      N/A        N/A   2015-03-18
# 1            N/A                      N/A        N/A   1970-01-01
# 2            N/A                      N/A        N/A   1970-01-01
# 3            N/A                      N/A        N/A   1970-01-01
# 4            N/A                      N/A        N/A   1970-01-01
# ...          ...         ...          ...        ...          ...
# 3048         N/A                      N/A        N/A   2023-06-19
# 3049         N/A                      N/A        N/A   2023-06-19
# 3050         N/A                      N/A        N/A   2023-06-19
# 3051         N/A                      N/A        N/A   2023-06-19
# 3052         N/A                      N/A        N/A   2023-06-19
#
#             stock_id  delisting index_option_type  main_contract  \
# 0      4440996184065      False               N/A          False
# 1                  2      False               N/A          False
# 2                  3      False               N/A          False
# 3                  4      False               N/A          False
# 4                  5      False               N/A          False
# ...              ...        ...               ...            ...
# 3048  83833466734314      False               N/A          False
# 3049  83833466737242      False               N/A          False
# 3050  83833466740242      False               N/A          False
# 3051  83833466740512      False               N/A          False
# 3052  83833466740612      False               N/A          False
#
#      last_trade_time exchange_type
# 0                     HK_MAINBOARD
# 1                     HK_MAINBOARD
# 2                     HK_MAINBOARD
# 3                     HK_MAINBOARD
# 4                     HK_MAINBOARD
# ...              ...           ...
# 3048                  HK_MAINBOARD
# 3049                  HK_MAINBOARD
# 3050                  HK_MAINBOARD
# 3051                  HK_MAINBOARD
# 3052                  HK_MAINBOARD
#
# [3053 rows x 17 columns]

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
